# %% [markdown]
# ![image.png](attachment:image.png)
#
# word embedding are of two typs:
# 1) frequecy based - bow, tfidf, glove
# 2) prediction based -  based on the predtion of an algorithm

# %%
import gensim

# %%
from gensim.models import Word2Vec, KeyedVectors

# %%
model =
